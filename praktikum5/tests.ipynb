# %%
from keras.datasets import mnist
from matplotlib import pyplot
 
(x_train, y_train), (x_test, y_test) = mnist.load_data()
 
for i in range(9):  
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(x_test[i], cmap=pyplot.get_cmap('gray'))
    pyplot.show()
    print("^ Actual", y_test[i])
# Out:
# 2022-06-17 15:42:36.275490: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-17 15:42:36.275540: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ^ Actual 7
# ^ Actual 2
# ^ Actual 1
# ^ Actual 0
# ^ Actual 4
# ^ Actual 1
# ^ Actual 4
# ^ Actual 9
# ^ Actual 5
